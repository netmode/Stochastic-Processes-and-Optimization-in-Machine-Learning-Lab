# %% [markdown]
# <h1><b>The k-means Algorithm</b></h1> <p align="justify">In this exercise you will study the unsupervised learning algorithm <a href="https://en.wikipedia.org/wiki/K-means_clustering"><i>k-means</i></a> by constructing a short program. For this exercise you will use the <i>Scikit-Learn</i> library of <i>Python</i>. Specifically, you will separate 150 examples of the <i>Iris</i> plant into <i>clusters</i>, based on the unlabeled dataset provided at the end of the assignment; using it, you can also build the single program that will be requested. The <i>features</i> included in the <i>dataset</i> that describe each example are: <i>sepal length</i>, <i>sepal width</i>, <i>petal length</i>, and <i>petal width</i>.</p> <p>You are asked to develop a single program that does the following:</p> <ul> <li>Implements the <a href="https://en.wikipedia.org/wiki/Elbow_method_(clustering)"><i>“Elbow”</i></a> method on the Iris sample, in order to identify an adequate number of <i>clusters</i>. What do you observe?</li> <li>Implements the <i>k-means</i> algorithm based on the number of <i>clusters</i> you found in the previous question. Describe how the algorithm works.</li> <li>Attempt to implement evaluations regarding the algorithm’s performance (<i>Accuracy</i>, <a href="https://en.wikipedia.org/wiki/Confusion_matrix"><i>Confusion Matrix values</i></a>).</li> </ul>

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
import sklearn.metrics as sm

import pandas as pd
import numpy as np

# %%
# import some data to play with (from sklearn)
iris = datasets.load_iris()
print(iris)

# %%
#print is optional
print(iris.data)
iris.feature_names
print(iris.target)
iris.target_names

# %%
# Store the inputs as a Pandas Dataframe and set the column names
x = pd.DataFrame(iris.data)
x.columns = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width']

# %%
y = pd.DataFrame(iris.target)
y.columns = ['Targets']
