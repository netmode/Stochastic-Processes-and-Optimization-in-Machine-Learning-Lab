# %% [markdown]
# <h1><b>Exercise 1</b></h1> <p align="justify">The following figure shows the floor plan of a house with five rooms: <i>Kitchen (<b>K</b>)</i>, <i>Library (<b>B</b>)</i>, <i>Living Room (<b>Σ</b>)</i>, <i>Bedroom (<b>Υ</b>)</i>, and <i>Bathroom (<b>Μ</b>)</i>, as well as the doors connecting them. A fly living in the house crosses each night, at random, one of the doors of the room in which it is located and remains in the room to which the door leads until the next night. Initially, the insect is in the <i>Bathroom</i>. If {X<sub>n</sub>}<sub>n</sub> is the Markov chain describing the position of the fly after n nights:</p> <ul> <li>Describe the state space X of the Markov chain.</li> <li>Determine the transition probability matrix P of the Markov chain.</li> </ul>
#
# <img src="https://raw.githubusercontent.com/netmode/Stochastic-Processes-and-Optimization-in-Machine-Learning-Lab/refs/heads/main/lab3/ex1.png"></img>
